# %%
# !pip install git+https://github.com/KameniAlexNea/feature-importance.git
# Out:
# ...
#   Cloning https://github.com/KameniAlexNea/feature-importance.git to /tmp/pip-req-build-geg0aash
#   Running command git clone --filter=blob:none --quiet https://github.com/KameniAlexNea/feature-importance.git /tmp/pip-req-build-geg0aash
#   Resolved https://github.com/KameniAlexNea/feature-importance.git to commit 43476c5ce4539142b99f990cb501339c15c8a4ec
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for f-importance: filename=f_importance-1.1.1-py3-none-any.whl size=14243 sha256=1973b2e7fe7885fe46296a193dc771e9fafcc797f8d7f37edc82e6e42a1d3988
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9erosvyd/wheels/41/a0/be/6b2e9ad22299f94fb9d83a866f06abf4b5d446c2c13cc37018
# Successfully built f-importance
# ...
#   Attempting uninstall: f-importance
#     Found existing installation: f-importance 1.1.1
#     Uninstalling f-importance-1.1.1:
# ...

# %%
from f_importance.util import runner

# %%
runner.__dict__
# Out:
# {'__name__': 'f_importance.util.runner',
#  '__doc__': None,
#  '__package__': 'f_importance.util',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7fac83cc94d0>,
#  '__spec__': ModuleSpec(name='f_importance.util.runner', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fac83cc94d0>, origin='/home/eak/Documents/AI/Library/feature-importance/.venv/lib/python3.11/site-packages/f_importance/util/runner.py'),
#  '__file__': '/home/eak/Documents/AI/Library/feature-importance/.venv/lib/python3.11/site-packages/f_importance/util/runner.py',
#  '__cached__': '/home/eak/Documents/AI/Library/feature-importance/.venv/lib/python3.11/site-packages/f_importance/util/__pycache__/runner.cpython-311.pyc',
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__package__': '',
# ...
